# %% [markdown]
# ## In this project, we will explore copper price trends and forecast them using time series analysis and machine learning models.
#
# ---

# %% [markdown]
# # Preparations

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm

plt.rcParams['figure.figsize'] = [10, 8]
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import yfinance as yf

# %% [markdown]
# ### Create time boundaries

# %% [markdown]
# Creating variables with time boundaries using the datetime library.

# %%
import datetime

years = 10
end_date = datetime.datetime.now()
start_date = datetime.datetime.now() - datetime.timedelta(days=years*365)

# %% [markdown]
# ### Load the data

# %%
ticker = "HG=F"

data = yf.download(ticker, start=start_date, end=end_date, interval='1mo')
data = data[['Adj Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Ploting function

# %%
def plot(x, y, title, xlabel, ylabel, grid_flg = True):
    plt.figure(figsize=(12, 6))
    plt.plot(x, y)
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(grid_flg)
    
    plt.show()

# %%
plot(data.index, data['Adj Close'], 'Copper (HG=F)', 'Date', 'Price, USD')

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Stationarity

# %% [markdown]
# ### Differencing

# %%
data['Adj Close Diff'] = data['Adj Close'].diff()

# %%
plot(data.index, data['Adj Close Diff'], 'Copper (HG=F)', 'Date', 'Price Diff, USD')

# %% [markdown]
# ### ADF Test

# %%
def adf_test(series):
    """Using an ADF test to determine if a series is stationary"""
    test_results = adfuller(series)
    print('ADF Statistic: ', test_results[0])
    print('P-Value: ', test_results[1])
    print('Critical Values:')
    for thres, adf_stat in test_results[4].items():
        print('\t%s: %.2f' % (thres, adf_stat))

# %%
adf_test(data["Adj Close"][1:])
# Out:
# ADF Statistic:  -1.0359596530787631
# P-Value:  0.739924011606121
# Critical Values:
# 	1%: -3.50
# 	5%: -2.89
# 	10%: -2.58

# %% [markdown]
# The p-value for the ADF test on the original time series is pretty high.
#
# Definitely, the original series is non-stationary.

# %%
adf_test(data["Adj Close Diff"][1:])
# Out:
# ADF Statistic:  -9.890459114054117
# P-Value:  3.5694156874461317e-17
# Critical Values:
# 	1%: -3.50
# 	5%: -2.89
# 	10%: -2.58

# %% [markdown]
# The p-value for the ADF test on the first-differenced data is remarkably small.
#
# The first difference is stationary, meaning that differencing has removed the trend or unit root.

# %% [markdown]
# ## Decomposition

# %%
data = data.dropna()

# %%
decomposition_plot_add = seasonal_decompose(data['Adj Close'],
                                            model='additive', period=12)
decomposition_plot_add.plot()
plt.show()

# %% [markdown]
# From the plot above we tried to capture the three components.
#
# However, we can only observe that there is a solid changing trend. The seasonal component has a really small influence.
#
# Also, we see the residuals having a higher volatility in the later years. From about 2021, the variance was higher.

# %% [markdown]
# ## Autocorrelation (ACF)

# %%
# Plot autocorrelation
plt.rc("figure", figsize=(12,6))
plot_acf(data['Adj Close'], lags=12)
plt.ylim(0,1)
plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# We do not observe any recognizable pattern on the graph, so we can not say there is seasonality in our data.
#
# The strength of correlation is generally and slowly decreasing as the lags increase. This points to a trend in our data, and it needs to be differenced to make it stationary when modeling.
#
# The blue region signifies which lags are statistically significant. Therefore, when building a forecast model for this data, the next month's forecast should probably only consider __7__ of the previous values due to their statistical significance.

# %% [markdown]
# ## Partial Autocorrelation (PACF)

# %%
plt.rc("figure", figsize=(12,6))
plot_pacf(data['Adj Close'], method='ywm')
plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Partial Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# The blue region is where lags are no longer statistically significant. We typically choose the number autoregressors by seeing how many of them are above the blue region. We see that lag __1__ is highly correlated.

# %% [markdown]
# # Forecasting

# %% [markdown]
# ## Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt, ExponentialSmoothing

train = data.iloc[:-int(len(data) * 0.2)]
test = data.iloc[-int(len(data) * 0.2):]

def plot_forecasts(forecast1: list[float],
         forecast2: list[float],
         forecast3: list[float], 
         title, xlabel, ylabel, grid_flg = True):
    
    plt.figure(figsize=(12, 6))
    plt.plot(train.index, train['Adj Close'], label="Train")
    plt.plot(test.index, test['Adj Close'], label="Test")
    plt.plot(test.index, forecast1, label="Simple Smoothing")
    plt.plot(test.index, forecast2, label="Holt's Linear")
    plt.plot(test.index, forecast3, label="Holt Winters")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(grid_flg)
    plt.legend()
    
    plt.show()


# Fit simple model and get forecasts
model_simple = SimpleExpSmoothing(train['Adj Close']).fit(optimized=True)
forecasts_simple = model_simple.forecast(len(test))

# Fit Holt's model and get forecasts
model_holt = Holt(train['Adj Close'], damped_trend=True).fit(optimized=True)
forecasts_holt = model_holt.forecast(len(test))

# Fit Holt Winters model and get forecasts
model_holt_winters = ExponentialSmoothing(train['Adj Close'], trend='mul',
                                          seasonal='add', seasonal_periods=12)\
                                          .fit(optimized=True)
forecasts_holt_winters = model_holt_winters.forecast(len(test))


# Plot the forecasts
plot_forecasts(forecasts_simple,
     forecasts_holt,
     forecasts_holt_winters,
     "Holt-Winters Exponential Smoothing", "Date", "Copper Price")

# %% [markdown]
# Simultaneously, we implemented three methods: Simple Exponential Smoothing, Holt’s Linear Trend Model and Holt-Winters Exponential Smoothing.
#
# Obviously, and as we can see, the first two are not really useful for forecasting complex time series. Simple exponential smoothing behaves as Naive Forecast when we believe that the next value will be the same as the value was before. Holt’s Linear Trend Model is not really much better than the previous one though it offers us not just a straight line but a curve line.
#
# The third approach gives a more interesting picture. We cannot say that the prediction is accurate, if at all we can say that it is at least somewhat suitable. But we can follow this line during our market decisions, we can use this line as an indicator or as a feature for ML models. However, we completely understand that there is no reason that future prices have to behave and to have the same pattern as previous prices did, because to say that this method gives us real forecasts.

# %% [markdown]
# ## Residuals

# %%
train['fittedvalues'] = model_holt_winters.fittedvalues
train['residuals'] = model_holt_winters.resid

# %% [markdown]
# ### Residual Correlation

# %%
fig, ax = plt.subplots(1,2,figsize=(8,3))
plot_acf(train['residuals'], lags=30, ax=ax[0])
ax[0].set_xlabel('Lags')
plot_pacf(train['residuals'], lags=30, ax=ax[1])
ax[1].set_xlabel('Lags')
plt.tight_layout()
plt.show()

# %% [markdown]
# Most of the correlations are below the non-statistically significant level, which means the residuals are not correlated.
#
# Also, there is no recognizable pattern in the correlations.

# %% [markdown]
# ### Ljung-Box Test

# %%
print(acorr_ljungbox(train['residuals'], return_df=True))
# Out:
#       lb_stat  lb_pvalue
# 1    0.000768   0.977885
# 2    5.496103   0.064053
# 3    5.497942   0.138762
# 4    5.507070   0.239109
# 5    5.880667   0.318004
# 6   11.891265   0.064439
# 7   12.069497   0.098296
# 8   12.211705   0.142005
# 9   13.693075   0.133670
# 10  13.848758   0.180003

# %% [markdown]
# We observe the p-values of the first 10 lags. They are all above the significance level of 0.05, therefore we accept the null hypothesis of no autocorrelation.

# %% [markdown]
# ### Histogram of Residuals

# %%
plt.figure(figsize=(10, 5))
plt.hist(train["residuals"])

plt.title("Distribution of Residuals")
plt.xlabel("Residuals")
plt.ylabel("Count")

plt.show()

print(train['residuals'].mean())
# Out:
# 0.00015496385048539583

# %% [markdown]
# In this case, the residuals are mostly distributed around zero with a mean of 0.00015 and, though there are slight distortions, we can say that the distribution well bell-shaped.

# %% [markdown]
# ## Autoregression

# %% [markdown]
# ### PACF

# %%
plt.rc("figure", figsize=(11,5))
plot_pacf(data['Adj Close Diff'], method='ywm')
plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Partial Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# The lags outside the blue shaded region are classed as significantly significant and should be included as the features for our autoregressive model. From the above plot, it seems lags 6, 11, 17 and 20 are significant.

# %% [markdown]
# ### Model

# %%
train = data.iloc[:-int(len(data) * 0.2)]
test = data.iloc[-int(len(data) * 0.2):]

model = AutoReg(train['Adj Close Diff'], lags=[6, 11, 17, 20]).fit()

# %% [markdown]
# To build a model we use stationary series which we have got after differencing.

# %% [markdown]
# ### Result

# %%
transformed_forecasts = list(model.forecast(steps=len(test)))
forecasts = []
for idx in range(len(test)):
    if idx == 0:
        forecast = transformed_forecasts[idx] + train['Adj Close'].iloc[-1]
    else:
        forecast = transformed_forecasts[idx] + forecasts[idx-1]

    forecasts.append(forecast)

# %% [markdown]
# Do not forget to implement a process opposite to differencing.

# %%
def plot_forecasts(forecast: list[float],
         title, xlabel, ylabel, grid_flg = True):
    
    plt.figure(figsize=(12, 6))
    plt.plot(train.index, train['Adj Close'], label="Train")
    plt.plot(test.index, test['Adj Close'], label="Test")
    plt.plot(test.index, forecast, label="Forecast")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(grid_flg)
    plt.legend()
    
    plt.show()

# %%
plot_forecasts(forecasts,
     "Autoregression", "Date", "Copper Price")

# %% [markdown]
# Again, as with Holt Winters Smoothing, we cannot say that the prediction is accurate. And again we can follow this line during our market decisions, we can use this line as an indicator or as a feature for ML models.

# %% [markdown]
# ## ARIMA

# %% [markdown]
# To implement ARIMA model we need 3 parameters: the (p,d,q) order of the model for the autoregressive, differences, and moving average components.
# We already got p = [6, 11, 17, 20] and d = 1 (the number of differencing we need to transform our series to a stanionary appearance).
# The only thing left is to get q parameter.

# %% [markdown]
# ### ACF

# %%
plt.rc("figure", figsize=(11,5))
plot_acf(data['Adj Close Diff'])
plt.xlabel('Lags', fontsize=18)
plt.ylabel('Correlation', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Autocorrelation Plot', fontsize=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# We can distinguish only two statistically significant lags: the 6th and the 11th, though the last one is arguable because it is on the border.

# %% [markdown]
# ### Model

# %%
train = data.iloc[:-int(len(data) * 0.2)]
test = data.iloc[-int(len(data) * 0.2):]

# Build ARIMA model and inverse the boxcox
model = ARIMA(train['Adj Close'], order=([6, 11, 17, 20], 1, [6, 11])).fit()
forecasts = model.forecast(len(test))

# %% [markdown]
# ### Result

# %%
plot_forecasts(forecasts,
     "ARIMA", "Date", "Copper Price")

# %% [markdown]
# It seems an interesting result. We see the model captures the direction of many price movements. However, there are many mistakes in movement amplitude and wrong movements in the end.
#
# Hard to say if this model shows better results than previous ones by eyes (in this project we don't estimate any metrics), but we can also orient and use this price line for other ML models as features.

# %% [markdown]
# ## ARIMAX & Fourier Series

# %% [markdown]
# The last approach we use is the ARIMAX model, which means an ARIMA model with exogenous features. As exogenous features, we will concern the Fourier series.

# %% [markdown]
# ### Fourier series

# %%
data['month_num'] = data.index.month

# Get fourier features
for order in range(1, 10):
    data[f'fourier_sin_order_{order}'] = np.sin(2 * np.pi * order * data['month_num'] / 12)
    data[f'fourier_cos_order_{order}'] = np.cos(2 * np.pi * order * data['month_num'] / 12)

# name of fourier features
fourier_features = [i for i in list(data) if i.startswith('fourier')]

# %% [markdown]
# ### Model

# %%
# Split train and test
train = data.iloc[:-int(len(data) * 0.2)]
test = data.iloc[-int(len(data) * 0.2):]

# Build auto-ARIMA model with fourier features
model = pm.auto_arima(train['Adj Close'],
                      X=train[fourier_features],
                      seasonal=False,
                      stepwise=True,
                      suppress_warnings=True,
                      max_order=None,
                      information_criterion='aicc',
                      error_action="ignore")

# Get the forecasts and apply inverse box-cox transform
forecasts = model.predict(n_periods=len(test), X=test[fourier_features])

# %% [markdown]
# ### Result

# %%
plot_forecasts(forecasts,
     "ARIMAX", "Date", "Copper Price")

# %% [markdown]
# We can observe an interesting coincidence that we quite closely captured half of the test data in the forecast but have larger residuals in the second half of the test data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Overall

# %% [markdown]
# In this project we implemented basic techniques of analyzing time series and implemented several ML models to forecast the data.

# %% [markdown]
# We questioned if the data was __stationary__ and removed trends by __differencing__. We are convinced of this due to __the Augmented Dickey–Fuller test__. The question about __seasonality__ in the data was solved by __decomposing__ the data. We saw a really small influence of the seasonal component. In addition, using __Autocorrelation__ and __Partial Autocorrelation__ plots, we considered the seasonality question again.

# %% [markdown]
# Four ML models were implemented to forecast the time series.
#
# The __Holt Winters model__, known as __Exponential Smoothing__, was the first one. After the model, obtained __residuals__ were evaluated and this showed us the success of building the model by their __normal distribution__. Also, we accepted the null hypothesis of __no autocorrelation__ among residuals by the __Ljung-Box test__
#
# The second model we implemented was the __Autoregression__ model. To choose which lags are statistically significant to be used in the model, we implemented __Partial Autocorrelation__ again but using __the first difference__ of the time series.
#
# The next well-known model that was chosen is the __ARIMA__ model. The model combines Autocorrelation (AR) and Moving Average models (MA) and these are used for Integrated (I) time series. To choose significant lags, we implemented __Autocorrelation__ over the first difference of the data.
#
# The last model was an advanced version of the ARIMA - __ARIMAX__. As exogenous features, we used the __Fouries Series__ to present our model as __Harmonic Regression__.

# %% [markdown]
# ## Results

# %% [markdown]
# The obtained results of 4 implemented models don't show accuracy in forecasting over the test data. It is seen by the eye, even without evaluating results by different metrics, which we left out of the project. The complicated nature of price movements gives a reasonable assessment of the complexity of such a task.
# However, all these results might be used as indicators, as orientiers for market strategy or as features for following ML models.

# %% [markdown]
# ## Further directions

# %% [markdown]
# Data analysis and ML models open a wide area of opportunities to research market movements like time series.
#
# Ideas for future research include using other more complex ML models such as LSTM or Transformer-based models.
#
# Also, using combinations of different market indicators, other commodity prices and macroeconomic indicators seems an ambitious plan to increase the accuracy of forecasting.
